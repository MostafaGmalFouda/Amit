# %%
print("Hello world")
# Out:
# Hello world

# %%
x=5
c=9
print("this is X:",x)
# Out:
# this is X: 5

# %%
name = input("enter your name: ")
age = int(input("Enter your age: "))
course_name = input("enter you course")

# %%
name = 'Mostafa'
id=20
course_name='Machine learning'

# %%
print ("My name is {} and my id is {} years old ,I am engaged in learning {}".format(name,id,course_name))
# Out:
# My name is Mostafa and my age is 20 years old ,I am engaged in learning Machine learning

# %%
print(f"My name is {name} and my id is {id} years old ,I am engaged in learning {course_name}")
# Out:
# My name is Mostafa and my age is 20 years old ,I am engaged in learning Machine learning

# %%
name= "depi learning"
name_1= name.replace("depi","depi_ML_")
name_1
# Out:
# 'depi_ML_ learning'

# %%
name_1.upper()
# Out:
# 'DEPI_ML_ LEARNING'

# %%
string_1="depi is depi is depi for learning"
string_1.count("depi")
# Out:
# 3

# %%
x= string_1.split()
print(type(x))
print(type(string_1))
# Out:
# <class 'list'>
# <class 'str'>

# %%
string_1 = "amit learning"
string_1.title()
# Out:
# 'Amit Learning'

# %%
response = ' '.join(x)
response
type(response)
# Out:
# str

# %%
response.startswith("t")
# Out:
# False

# %%
response.endswith('i')
# Out:
# False

# %%
print("welcome to depi \n\"machine learning course\"")
# Out:
# welcome to depi
# "machine learning course"

# %%
list_1=[1,2,3,4,"depi","learning",True,[1,2,3,"True",["ml","dl","cv","nlp"]]]

# %%
list_2=[1,2,3,4,"depi","learning",True,[1,2,3,"True",["ml","dl","cv","nlp"]]]

# %%
list_1[7][4][0]
# Out:
# 'ml'

# %%
list_1[7][4][0]="Ds"

# %%
list_1
# Out:
# [1,
#  2,
#  3,
#  4,
#  'depi',
#  'learning',
#  True,
#  [1, 2, 3, 'True', ['Ds', 'dl', 'cv', 'nlp']]]

# %%
x = "Amit"
y=list(x)
y
# Out:
# ['A', 'm', 'i', 't']

# %%
list_3 = list_1+list_2
list_3
# Out:
# [1,
#  2,
#  3,
#  4,
#  'depi',
#  'learning',
#  True,
#  [1, 2, 3, 'True', ['Ds', 'dl', 'cv', 'nlp']],
#  1,
#  2,
#  3,
#  4,
#  'depi',
#  'learning',
#  True,
#  [1, 2, 3, 'True', ['ml', 'dl', 'cv', 'nlp']]]

# %%
L_1= [1,2,3,6,6,6,5,5,2,1]
L_2=[4,5,6]
L_3=[7,8,9]
L_1.extend(L_2)
L_1
# Out:
# [1, 2, 3, 6, 6, 6, 5, 5, 2, 1, 4, 5, 6]

# %%
L_1.remove(3)
L_1
# Out:
# [1, 2, 4, 5, 6]

# %%
L_1.pop(1)
L_1
# Out:
# [4]

# %%
del L_1[0]

# %%
L_1
# Out:
# [2, 3, 4, 5, 6]

# %%
name = 'Mostafa'
id=20
course_name='Machine learning'
print ("My name is {} and my id is {} years old ,I am engaged in learning {}".format(name,id,course_name))
print(f"My name is {name} and my id is {id} years old ,I am engaged in learning {course_name}")
# Out:
# My name is Mostafa and my id is 20 years old ,I am engaged in learning Machine learning
# My name is Mostafa and my id is 20 years old ,I am engaged in learning Machine learning

# %%
input_list = ["depi","learning","python"]
item = input("enter your item.")
input_list.remove(item)
print(f"output list is {input_list}")
# Out:
# output list is ['learning', 'python']

# %%
L_1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
index_val = L_1.index(5)
index_val
# Out:
# 4

# %%
L_1.count(6)
# Out:
# 4

# %%
L_1.sort(reverse=True)
L_1
# Out:
# [6, 6, 6, 6, 5, 5, 5, 4, 3, 2, 2, 1, 1]

# %%
L_1.reverse()
L_1
# Out:
# [1, 1, 2, 2, 3, 4, 5, 5, 5, 6, 6, 6, 6]

# %%
tuple_1 = tuple(L_1)
tuple_1[0]
# Out:
# 1

# %%
set_1 = set(L_1)
set_1
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set_2 = set(L_2)
set_2
# Out:
# {4, 5, 6}

# %%
print(set_1.intersection(set_2))
# Out:
# {4, 5, 6}

# %%
print(set_1.union(set_2))
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
print(set_1.difference(set_2))
# Out:
# {1, 2, 3}

# %%
set_1.discard(1)
set_1
# Out:
# {2, 3, 4, 5, 6}

# %%
set_1 = {1,2,3,4,5,6,"p"}
set_1
# Out:
# {1, 2, 3, 4, 5, 6, 'p'}

# %%
dict_1 = {"key_1":[1,2,3]}
dict_1["key_1"]
# Out:
# [1, 2, 3]

# %%
2!=5
# Out:
# True

# %%
num_1 = float(input("inter your num_1"))
num_2 = float(input("inter your num_2"))
print(f"addition = {num_1+num_2}")
print(f"subtraction = {num_1-num_2}")
print(f"multiplication = {num_1*num_2}")
print(f"division = {num_1/num_2}")
# Out:
# addition = 15.0
# subtraction = 5.0
# multiplication = 50.0
# division = 2.0

# %%
num_1 = float(input("inter your num_1"))
num_2 = float(input("inter your num_2"))
num_3 = float(input("enter your num_3"))
if num_1>num_2:
    print("done_1")
elif num_1>num_3:
    print("done_2")
elif num_2>num_3:
    print("done_3")
elif num_3>num_2:
    print("done_4")
else:
    print("done_5")
# Out:
# done_1

# %%
a = 10
b = 5
result= a+b if a>b else a-b
result
# Out:
# 15

# %%
degree = float(input("enter you degree"))
if 0<= degree <=100 : 
    if degree >= 85 :
        print ("A")
    elif degree >= 75:
        print("B")
    elif degree>= 65:
        print("C")
    elif degree >= 50:
        print("D")
    else:
        print("F")
else:
    print("error")
# Out:
# C
