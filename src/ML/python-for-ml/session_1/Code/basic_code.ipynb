# %%
print("Hello world")
# Out:
# Hello world

# %%
x=5
c=9
print("this is X:",x)
# Out:
# this is X: 5

# %%
name = input("enter your name: ")
age = int(input("Enter your age: "))
course_name = input("enter you course")

# %%
name = 'Mostafa'
age=20
course_name='Machine learning'

# %%
print ("My name is {} and my age is {} years old ,I am engaged in learning {}".format(name,age,course_name))
# Out:
# My name is Mostafa and my age is 20 years old ,I am engaged in learning Machine learning

# %%
print(f"My name is {name} and my age is {age} years old ,I am engaged in learning {course_name}")
# Out:
# My name is Mostafa and my age is 20 years old ,I am engaged in learning Machine learning

# %%
name= "depi learning"
name_1= name.replace("depi","depi_ML_")
name_1
# Out:
# 'depi_ML_ learning'

# %%
name_1.upper()
# Out:
# 'DEPI_ML_ LEARNING'

# %%
string_1="depi is depi is depi for learning"
string_1.count("depi")
# Out:
# 3

# %%
x= string_1.split()
print(type(x))
print(type(string_1))
# Out:
# <class 'list'>
# <class 'str'>

# %%
string_1 = "amit learning"
string_1.title()
# Out:
# 'Amit Learning'

# %%
response = ' '.join(x)
response
type(response)
# Out:
# str

# %%
response.startswith("t")
# Out:
# False

# %%
response.endswith('i')
# Out:
# False

# %%
print("welcome to depi \n\"machine learning course\"")
# Out:
# welcome to depi
# "machine learning course"
